# %%
import numpy as np
import pandas as pd
import os
import itertools as it
import time

# %%
pd.options.display.max_rows = 500

# %%
# file = ''
# for i in os.listdir():
#     if 'NBA' in i:
#         file = i

# %%
raw = pd.read_csv('FanDuel-NBA-2019-04-07-34300-players-list.csv')

# %%
# raw

# %%
raw.columns
# Out:
# Index(['Id', 'Position', 'First Name', 'Nickname', 'Last Name', 'FPPG',
#        'Played', 'Salary', 'Game', 'Team', 'Opponent', 'Injury Indicator',
#        'Injury Details', 'Tier', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
df = raw.drop(['Id', 'First Name', 'Last Name', 'Played', 'Game', 'Injury Details', 'Unnamed: 14', 'Unnamed: 15', 'Tier'], axis=1)

# %%
df = df[(df['Injury Indicator'] != 'O')]
df = df[(df['Injury Indicator'] != 'GTD')]
df.drop('Injury Indicator', axis=1, inplace=True)
df.Position.unique()
# Out:
# array(['PG', 'SG', 'C', 'SF', 'PF'], dtype=object)

# %%
df
# Out:
#     Position                  Nickname       FPPG  Salary Team Opponent
# 0         PG         Russell Westbrook  54.657143   12000  OKC      DET
# 1         SG              James Harden  58.322368   12000  HOU       NY
# 2          C            Andre Drummond  46.300000   10900  DET      OKC
# 3          C        Karl-Anthony Towns  48.586843   10700  MIN      MIA
# 4          C               Rudy Gobert  41.929487   10500  UTA      SAC
# 5         SF               Paul George  49.075999   10000  OKC      DET
# 7          C              Nikola Jokic  46.697435    9800  DEN      POR
# 8          C            Nikola Vucevic  44.910125    9700  ORL      ATL
# 9         SG          Donovan Mitchell  37.310667    9700  UTA      SAC
# 10        SF              Kevin Durant  45.434211    9500   GS      CLE
# 11        PG             Stephen Curry  44.077611    9400   GS      CLE
# 12        PG            Damian Lillard  43.744873    9400  POR      DEN
# 15        PG              Kyrie Irving  43.942424    9000  BOS      IND
# 16        PG              Kemba Walker  41.564558    9000  CHA      TOR
# 17        PF             Julius Randle  37.569444    9000   NO      PHO
# 18        SG              Bradley Beal  43.873749    8900  WAS       SA
# 19        PG                Trae Young  35.002499    8900  ATL      ORL
# 20        PF         LaMarcus Aldridge  39.106328    8800   SA      WAS
# 21         C              Clint Capela  39.007812    8800  HOU       NY
# 23        PG                Chris Paul  37.512726    8700  HOU       NY
# 24         C         Mitchell Robinson  24.706452    8700   NY      HOU
# 25        SF             Kawhi Leonard  45.027588    8600  TOR      CHA
# 28        SG             DeMar DeRozan  40.200001    8300   SA      WAS
# 29         C             Thomas Bryant  22.779711    8100  WAS       SA
# 31         C              JaVale McGee  28.247223    7900  LAL      LAC
# 33         C              Myles Turner  33.611111    7900  IND      BOS
# 36        PF              John Collins  34.553333    7700  ATL      ORL
# 38        PF             Pascal Siakam  32.870130    7600  TOR      CHA
# 39        PG              De'Aaron Fox  36.697470    7600  SAC      UTA
# 40        SG             Klay Thompson  33.765789    7500   GS      CLE
# 41        SF          Danilo Gallinari  32.483332    7500  LAC      LAL
# 42        PF               Bam Adebayo  24.346154    7500  MIA      MIN
# 43        PF          Montrezl Harrell  32.400001    7400  LAC      LAL
# 44        PG               Rajon Rondo  28.820001    7400  LAL      LAC
# 47        PG              Jamal Murray  32.027778    7300  DEN      POR
# 48        PF              Aaron Gordon  32.550667    7300  ORL      ATL
# 49         C               Enes Kanter  28.548437    7200  POR      DEN
# 50        PF           Larry Nance Jr.  28.203125    7200  CLE       GS
# 51         C              Steven Adams  33.736842    7200  OKC      DET
# 52        PG             Elfrid Payton  29.182051    7200   NO      PHO
# 54        SG            Andrew Wiggins  30.571013    7200  MIN      MIA
# 55        SG               Buddy Hield  32.388607    7100  SAC      UTA
# 56        PF            Draymond Green  31.268254    7100   GS      CLE
# 58        SF                Joe Ingles  27.465385    7100  UTA      SAC
# 60        SG              Lou Williams  31.883335    7000  LAC      LAL
# 62        SG              Delon Wright  20.043662    7000  MEM      DAL
# 63        PF            Christian Wood  12.766667    6800   NO      PHO
# 65        PF            Thaddeus Young  28.717721    6700  IND      BOS
# 66        SF          Bojan Bogdanovic  27.072151    6600  IND      BOS
# 68        PF         Marvin Bagley III  28.211666    6600  SAC      UTA
# 69        PF          Domantas Sabonis  30.588888    6600  IND      BOS
# 70        PF              Bobby Portis  27.961701    6500  WAS       SA
# 72        PG              Goran Dragic  25.462500    6500  MIA      MIN
# 73        PF                 Ivan Rabb  12.704445    6500  MEM      DAL
# 74        SG           Jordan Clarkson  25.880769    6400  CLE       GS
# 75        PG                Kyle Lowry  35.542187    6400  TOR      CHA
# 77        PF              Paul Millsap  29.055223    6400  DEN      POR
# 78        PG   Shai Gilgeous-Alexander  22.589999    6400  LAC      LAL
# 79        PF              Jayson Tatum  30.437181    6400  BOS      IND
# 80        SG               Dwyane Wade  26.976812    6300  MIA      MIN
# 81        PG             Collin Sexton  23.927849    6300  CLE       GS
# 83        SG  Kentavious Caldwell-Pope  18.205063    6200  LAL      LAC
# 85         C                Marc Gasol  34.664474    6000  TOR      CHA
# 86        PG              Terry Rozier  20.665789    6000  BOS      IND
# 87        SG             Evan Fournier  25.441026    5800  ORL      ATL
# 88        SF                Cedi Osman  23.651351    5800  CLE       GS
# 89        SF             Mikal Bridges  20.456962    5800  PHO       NO
# 90        PG                Tyus Jones  18.956249    5800  MIN      MIA
# 91        PF              Josh Jackson  22.265789    5800  PHO       NO
# 93        SF                  Rudy Gay  28.251515    5700   SA      WAS
# 94        PG             Derrick White  23.714062    5700   SA      WAS
# 95        PG             Fred VanVleet  23.585245    5700  TOR      CHA
# 96        PF               Serge Ibaka  30.525001    5700  TOR      CHA
# 97         C            DeAndre Jordan  32.846375    5600   NY      HOU
# 98        PG          Tomas Satoransky  22.610390    5600  WAS       SA
# 99        SF            Jonathan Isaac  23.005480    5600  ORL      ATL
# 100        C          Hassan Whiteside  33.469564    5500  MIA      MIN
# 101       PG             D.J. Augustin  22.811539    5500  ORL      ATL
# 103       SF                Kevin Knox  20.668055    5500   NY      HOU
# 106       SG             Terrence Ross  23.817949    5400  ORL      ATL
# 107       SF            Gordon Hayward  23.808571    5400  BOS      IND
# 108       SG              Marcus Smart  23.343590    5400  BOS      IND
# 109       SG               Jeremy Lamb  28.138665    5400  CHA      TOR
# 110       PF              Jerami Grant  26.506579    5400  OKC      DET
# 111       SG         Bogdan Bogdanovic  26.372060    5400  SAC      UTA
# 113       SF           Justise Winslow  27.267742    5300  MIA      MIN
# 114       SF          Maurice Harkless  19.950876    5300  POR      DEN
# 115       SG              Dion Waiters  20.845000    5300  MIA      MIN
# 120       PG            Reggie Jackson  25.451281    5200  DET      OKC
# 122       PG               Alex Caruso  16.045455    5200  LAL      LAC
# 125        C             Mason Plumlee  23.206410    5100  DEN      POR
# 127       PF               Maxi Kleber  17.997102    5100  DAL      MEM
# 129       PF           Al-Farouq Aminu  22.967949    5000  POR      DEN
# 130       PF             Dragan Bender  11.553488    5000  PHO       NO
# 131        C               Ivica Zubac  19.535714    5000  LAC      LAL
# 132       SG           Dennis Schroder  26.346667    5000  OKC      DET
# 133       SG               Eric Gordon  23.389232    5000  HOU       NY
# 134        C                  Alex Len  21.133784    5000  ATL      ORL
# 135       SF             Bruno Caboclo  17.586666    5000  MEM      DAL
# 136       SF          Kenrich Williams  16.920930    4900   NO      PHO
# 137       SF             Miles Bridges  16.492106    4900  CHA      TOR
# 138       SG               Josh Okogie  17.236620    4900  MIN      MIA
# 139       SG           Wayne Ellington  17.197959    4900  DET      OKC
# 140       PF               Dario Saric  20.132467    4900  MIN      MIA
# 141       SF               Evan Turner  18.358571    4800  POR      DEN
# 142       SF           Harrison Barnes  25.491892    4800  SAC      UTA
# 143        C         Willy Hernangomez  16.630357    4800  CHA      TOR
# 144       SF          Lance Stephenson  14.955882    4700  LAL      LAC
# 145       SG            Damyean Dotson  19.794204    4700   NY      HOU
# 146       SF             Mario Hezonja  16.869091    4700   NY      HOU
# 147       SF            Justin Jackson  13.085714    4700  DAL      MEM
# 148       PF              Zach Collins  15.679452    4700  POR      DEN
# 149       SF               Will Barton  23.325641    4700  DEN      POR
# 150       PF              Kelly Olynyk  20.570667    4600  MIA      MIN
# 152        C               Aron Baynes  14.428571    4600  BOS      IND
# 153       PF               Luke Kornet  14.859523    4500   NY      HOU
# 154       SF           DeAndre' Bembry  20.665822    4500  ATL      ORL
# 155       SG            Justin Holiday  21.862821    4500  MEM      DAL
# 156       SG            Jamal Crawford  13.677049    4500  PHO       NO
# 160       SG              Jordan McRae  10.965385    4500  WAS       SA
# 162        C                Ante Zizic  16.317857    4300  CLE       GS
# 163       SF          Chandler Parsons  14.331818    4300  MEM      DAL
# 165       SG              Troy Daniels   9.939583    4300  PHO       NO
# 166       SF              Tyreke Evans  18.722388    4300  IND      BOS
# 167       SG               Danny Green  21.114286    4300  TOR      CHA
# 168       PG   Michael Carter-Williams  13.368000    4300  ORL      ATL
# 169       SF               Gary Harris  22.458491    4300  DEN      POR
# 170       PF            JaMychal Green  20.435938    4200  LAC      LAL
# 171       PF            Frank Kaminsky  14.309302    4200  CHA      TOR
# 173       PG               Bryn Forbes  19.153164    4200   SA      WAS
# 175       SF         Derrick Jones Jr.  16.747368    4200  MIA      MIN
# 176       SF                Jeff Green  21.693244    4200  WAS       SA
# 177       SG              Monte Morris  20.853846    4200  DEN      POR
# 178       PG                Trey Burke  18.194444    4200  DAL      MEM
# 179       SF            Troy Brown Jr.  10.648979    4200  WAS       SA
# 180        C             Jahlil Okafor  15.691072    4200   NO      PHO
# 182       SF           Stanley Johnson  14.960606    4200   NO      PHO
# 183        C              Jakob Poeltl  16.597297    4100   SA      WAS
# 184       PG            Brandon Knight  11.763889    4100  CLE       GS
# 187       PF            Meyers Leonard  12.494915    4100  POR      DEN
# 188       SF               Rodney Hood  18.673913    4100  POR      DEN
# 189       PG             Landry Shamet  14.509210    4100  LAC      LAL
# 190       PF                 PJ Tucker  21.583544    4100  HOU       NY
# 192        C               Salah Mejri  10.242424    4000  DAL      MEM
# 193       SF             Nicolas Batum  24.315493    4000  CHA      TOR
# 195       PF            Kenneth Faried  21.897144    3900  HOU       NY
# 196       PG               Cory Joseph  19.649368    3900  IND      BOS
# 197       SG                 Ian Clark   9.780702    3900   NO      PHO
# 199       PF             Cheick Diallo  14.701639    3900   NO      PHO
# 200       PF                Khem Birch  12.878723    3900  ORL      ATL
# 201       SG             Aaron Holiday  11.002127    3900  IND      BOS
# 202       SF              Danuel House  16.994444    3900  HOU       NY
# 203       SG              Tyler Dorsey  10.031818    3900  MEM      DAL
# 204       SG           Jimmer Fredette   9.075000    3800  PHO       NO
# 205       PF        Johnathan Williams  11.533333    3800  LAL      LAC
# 206       PF             Dirk Nowitzki  11.877083    3800  DAL      MEM
# 207        C              Gorgui Dieng  14.597222    3800  MIN      MIA
# 208        C              Mike Muscala  14.942623    3800  LAL      LAC
# 212       PG         De'Anthony Melton  16.774469    3800  PHO       NO
# 213        C             Moritz Wagner   8.750000    3800  LAL      LAC
# 215        C                 Ekpe Udoh   6.274468    3700  UTA      SAC
# 216       SF           Nemanja Bjelica  22.921621    3700  SAC      UTA
# 217       SF             Davis Bertans  16.235616    3700   SA      WAS
# 218        C              Kevon Looney  17.994737    3700   GS      CLE
# 222       SG              Dwayne Bacon  11.479487    3700  CHA      TOR
# 223       SG             Malik Beasley  17.623377    3700  DEN      POR
# 224       PG            Jerryd Bayless  14.454545    3700  MIN      MIA
# 226       PG              Jevon Carter   9.908571    3700  MEM      DAL
# 227       PG           Devonte' Graham  11.435714    3700  CHA      TOR
# 228       PF             James Johnson  17.284314    3700  MIA      MIN
# 229       SG                Malik Monk  14.673913    3700  CHA      TOR
# 230        C                Thon Maker  12.878334    3600  DET      OKC
# 231        C           Bismack Biyombo  13.188000    3600  CHA      TOR
# 233       PG                Quinn Cook  11.618571    3600   GS      CLE
# 234       SG             Austin Rivers  15.895891    3600  HOU       NY
# 238       SF           Julian Washburn   7.571429    3600  MEM      DAL
# 239       SF              Vince Carter  14.328767    3600  ATL      ORL
# 241       PG              Troy Caupain   5.650000    3600  ORL      ATL
# 242       SF            Mitchell Creek   9.375000    3600  MIN      MIA
# 243       SG             C.J. Williams   4.115385    3600  MIN      MIA
# 245       PG                Elie Okobo  12.042000    3600  PHO       NO
# 247       PF             Jonas Jerebko  14.347826    3600   GS      CLE
# 248       SG              Torrey Craig  13.983098    3600  DEN      POR
# 249       SG            Garrett Temple  16.599999    3600  LAC      LAL
# 250       SG         Terrance Ferguson  12.068571    3600  OKC      DET
# 252       SF          Alfonzo McKinnie  10.244117    3500   GS      CLE
# 253       PF           Isaac Humphries   0.000000    3500  ATL      ORL
# 254       PF           Amile Jefferson   5.180000    3500  ORL      ATL
# 255       PF         Patrick Patterson   8.450820    3500  OKC      DET
# 256       SF              Solomon Hill  11.078049    3500   NO      PHO
# 257       SF            Wesley Johnson   8.128947    3500  WAS       SA
# 258       SG          Quincy Pondexter   3.976000    3500   SA      WAS
# 259       SF            Devin Robinson  10.600000    3500  WAS       SA
# 260       PF                Trey Lyles  16.442858    3500  DEN      POR
# 261       SG             Deonte Burton   5.370000    3500  OKC      DET
# 262       SG       Sindarius Thornwell   2.804918    3500  LAC      LAL
# 264       PF           Marquese Chriss  10.002500    3500  CLE       GS
# 266       SG           Duncan Robinson   4.353846    3500  MIA      MIN
# 267       PG                Jeremy Lin  18.094445    3500  TOR      CHA
# 270       PF        Guerschon Yabusele   4.800000    3500  BOS      IND
# 271       SF       Juancho Hernangomez  13.254412    3500  DEN      POR
# 272       SG                Alec Burks  17.968750    3500  SAC      UTA
# 273       PF           Markieff Morris  18.896297    3500  OKC      DET
# 276       PG              Shelvin Mack  16.075438    3500  CHA      TOR
# 277       PF                 Jon Leuer   7.880000    3500  DET      OKC
# 279       PG              Yogi Ferrell  11.350000    3500  SAC      UTA
# 280       PG                 Ish Smith  18.121154    3500  DET      OKC
# 281       PG             Isaiah Thomas  11.600000    3500  DEN      POR
# 282       SF               Jake Layman  14.356717    3500  POR      DEN
# 284        C             Zaza Pachulia  11.860000    3500  DET      OKC
# 285       SF             Yuta Watanabe   6.192308    3500  MEM      DAL
# 286       SF        Glenn Robinson III   7.470455    3500  DET      OKC
# 287       PG            Raymond Felton   8.462069    3500  OKC      DET
# 288       SG              Nik Stauskas  10.481818    3500  CLE       GS
# 289        C            Tyson Chandler  12.489091    3500  LAL      LAC
# 290       SF         Jaron Blossomgame  10.559259    3500  CLE       GS
# 292       SF               Abdel Nader   7.722034    3500  OKC      DET
# 294        C              Nerlens Noel  16.586302    3500  OKC      DET
# 295       PG               Kalin Lucas   7.100000    3500  DET      OKC
# 298        C                      Nene  10.040000    3500  HOU       NY
# 299       SG            Dairis Bertans   4.688889    3500   NO      PHO
# 300       PG               Daryl Macon   2.600000    3500  DAL      MEM
# 301       PG              Trevon Duval   3.066667    3500  HOU       NY
# 302       SG                Davon Reed   1.175000    3500  IND      BOS
# 303       SF                 Ben Moore   1.350000    3500   SA      WAS
# 304       PF             Udonis Haslem   2.300000    3500  MIA      MIN
# 305       PF            Malcolm Miller   4.811111    3500  TOR      CHA
# 306       SG           Rodney McGruder  15.821875    3500  MIA      MIN
# 307       PG              Devin Harris  11.984375    3500  DAL      MEM
# 308       SF    Michael Kidd-Gilchrist  15.529032    3500  CHA      TOR
# 309       SG              Courtney Lee   7.758065    3500  DAL      MEM
# 310       PG            Brad Wanamaker   7.306061    3500  BOS      IND
# 311       SF           Wilson Chandler  15.443750    3500  LAC      LAL
# 313       SF           Thabo Sefolosha   9.223913    3500  UTA      SAC
# 317       PF             Channing Frye   6.561765    3500  CLE       GS
# 318       SF              Semi Ojeleye   5.827778    3500  BOS      IND
# 320       PF               Yante Maten   0.000000    3500  MIA      MIN
# 321       SF              Lance Thomas   9.313333    3500   NY      HOU
# 323       PG               Tony Parker  16.948214    3500  CHA      TOR
# 325       PG             Jose Calderon   7.906250    3500  DET      OKC
# 326       PG           Brandon Goodwin   2.787500    3500  DEN      POR
# 329        C              Kosta Koufos  11.819512    3500  SAC      UTA
# 330       PG               Jordan Loyd   3.600000    3500  TOR      CHA
# 332       PF           Skal Labissiere   4.838095    3500  POR      DEN
# 335       PF           Tyler Cavanaugh   1.225000    3500  UTA      SAC
# 336       PF         Marcus Derrickson   4.344444    3500   GS      CLE
# 338       PF             Chris Boucher   7.725926    3500  TOR      CHA
# 339       SG           Naz Mitrou-Long   1.263636    3500  UTA      SAC
# 340       PF             Georges Niang   5.856364    3500  UTA      SAC
# 341       PF              Daniel Theis  13.828572    3500  BOS      IND
# 342       SF              Gerald Green  14.884286    3500  HOU       NY
# 343       SG            Tyrone Wallace   7.311864    3500  LAC      LAL
# 344       PG              Jerian Grant  11.722033    3500  ORL      ATL
# 345       PF          Johnathan Motley   8.000000    3500  LAC      LAL
# 346       PG               Jawun Evans   5.485715    3500  OKC      DET
# 347       PF            Caleb Swanigan   5.542105    3500  SAC      UTA
# 348       SG                 PJ Dozier   2.840000    3500  BOS      IND
# 349       SF               Tyler Lydon   2.120833    3500  DEN      POR
# 350       SF             Troy Williams  12.777778    3500  SAC      UTA
# 351       PF          Anthony Tolliver  10.226229    3500  MIN      MIA
# 353       PG           Jerome Robinson   6.046666    3500  LAC      LAL
# 356       SF               George King   1.200000    3500  PHO       NO
# 357       SG                 RJ Hunter   7.300000    3500  BOS      IND
# 358       SF          Keita Bates-Diop  11.126923    3500  MIN      MIA
# 359       PG               Patty Mills  17.932911    3500   SA      WAS
# 360       SF          Dante Cunningham   9.462903    3500   SA      WAS
# 361       SG            Gary Trent Jr.   2.485714    3500  POR      DEN
# 362       SG               Bruce Brown  11.327143    3500  DET      OKC
# 363       SG               Jacob Evans   2.460714    3500   GS      CLE
# 364       SG            Hamidou Diallo   7.978000    3500  OKC      DET
# 365       PF             Chimezie Metu   4.231034    3500   SA      WAS
# 366       SG          Lonnie Walker IV   5.878572    3500   SA      WAS
# 367        C               Ian Mahinmi  12.181250    3500  WAS       SA
# 368        C       Robert Williams III   9.760000    3500  BOS      IND
# 369       SG             Grayson Allen   5.464706    3500  UTA      SAC
# 371       SF           Vincent Edwards   2.700000    3500  HOU       NY
# 372       SG           Anfernee Simons   2.466667    3500  POR      DEN
# 373       SG               David Nwaba  14.600000    3500  CLE       GS
# 374        C              Thomas Welsh   2.663636    3500  DEN      POR
# 375       PF             Alize Johnson   1.550000    3500  IND      BOS
# 376       SG               Jodie Meeks  10.385714    3500  TOR      CHA
# 377       SF         Jarred Vanderbilt   4.126667    3500  DEN      POR
# 378       SF        Melvin Frazier Jr.   2.500000    3500  ORL      ATL
# 379       SF                Sam Dekker  13.652273    3500  WAS       SA
# 380       SG              Khyri Thomas   5.375000    3500  DET      OKC
# 381       SF               Isaac Bonga   4.289474    3500  LAL      LAC
# 382       PF      Kostas Antetokounmpo   4.100000    3500  DAL      MEM
# 383       PF              Ray Spalding   5.845455    3500  PHO       NO
# 384       SG               J.P. Macura   9.400000    3500  CHA      TOR
# 385       PG             Chris Chiozza   2.320000    3500  HOU       NY
# 388       SF                Wes Iwundu  11.250769    3500  ORL      ATL
# 389       SG             Dusty Hannahs   9.350000    3500  MEM      DAL
# 390        C               Jordan Bell  10.357813    3500   GS      CLE
# 391       SG            Chasson Randle  10.302174    3500  WAS       SA
# 392       PF            Jemerrio Jones   9.033333    3500  LAL      LAC
# 393       SG              Jaylen Adams   8.280646    3500  ATL      ORL
# 394       SG         Langston Galloway  13.976315    3500  DET      OKC
# 395       SF            Doug McDermott  10.555405    3500  IND      BOS
# 396       SG             Jared Terrell   3.663636    3500  MIN      MIA
# 397       PF            Ryan Broekhoff   6.634211    3500  DAL      MEM
# 398        C             Angel Delgado   5.400000    3500  LAC      LAL
# 399       SG             Billy Garrett   0.000000    3500   NY      HOU
# 400       PF             Jarell Martin   5.910256    3500  ORL      ATL
# 401       PG          Isaiah Whitehead  10.450000    3500  DET      OKC
# 402       SF            Donte Grantham   0.000000    3500  OKC      DET
# 403       SF                 Deng Adel   3.817647    3500  CLE       GS
# 404       SG          Cameron Reynolds   8.440000    3500  MIN      MIA
# 405       PF            Henry Ellenson  10.826666    3500   NY      HOU
# 406       PG             Edmond Sumner   5.625000    3500  IND      BOS
# 407       SF             Royce O'Neale  13.514102    3500  UTA      SAC
# 409       SF             Norman Powell  14.987719    3500  TOR      CHA
# 412       PF                   TJ Leaf   7.361818    3500  IND      BOS
# 413        C              Tony Bradley   2.600000    3500  UTA      SAC
# 414       PF        Isaiah Hartenstein   6.282143    3500  HOU       NY
# 415       SG              Justin Bibbs   0.000000    3500  LAC      LAL
# 416       SG                Damion Lee   7.682143    3500   GS      CLE
# 417       SF                BJ Johnson   5.766666    3500  SAC      UTA
# 418       SF              John Jenkins   5.713636    3500   NY      HOU
# 419       SF                Gary Clark   8.693878    3500  HOU       NY
# 420       SG               Frank Mason  10.308334    3500  SAC      UTA
# 421        C              Kyle O'Quinn  10.073810    3500  IND      BOS
# 422       PF              Drew Eubanks   4.766667    3500   SA      WAS

# %%
pg = df[df.Position == 'PG']
sg = df[df.Position == 'SG']
sf = df[df.Position == 'SF']
c = df[df.Position == 'C']
pf = df[df.Position == 'PF']

# %%
# def position(df):
#     pos = df.assing(foo=1).merge(df.assign(foo=1), on='foo').drop('foo', 1)
#     pos = pos[pos.Nickname_x != pos.Nickname_y]

# %% [markdown]
# ### PG's

# %%
pgs = pg.assign(foo=1).merge(pg.assign(foo=1), on='foo').drop('foo', 1)
pgs.shape
# Out:
# (3364, 12)

# %%
pgs = pgs[pgs.Nickname_x != pgs.Nickname_y]

# %%
pgs['ffpg'] = pgs.FPPG_x + pgs.FPPG_y
pgs['salary'] = pgs.Salary_x + pgs.Salary_y
pgs_no_opps = pgs[pgs.Team_x != pgs.Opponent_y]
pgs.drop(['Position_x', 'FPPG_x', 'Salary_x', 'Team_x', 'Opponent_x', 'Position_y', 'FPPG_y', 
         'Salary_y', 'Team_y', 'Opponent_y'], axis=1, inplace=True)

# %%
pgs.shape
# Out:
# (3306, 4)

# %% [markdown]
# ### SG's

# %%
sg.shape
# Out:
# (76, 6)

# %%
sgs = sg.assign(foo=1).merge(sg.assign(foo=1), on='foo').drop('foo', 1)
sgs = sgs[sgs.Nickname_x != sgs.Nickname_y]
sgs['ffpg'] = sgs.FPPG_x + sgs.FPPG_y
sgs['salary'] = sgs.Salary_x + sgs.Salary_y
sgs_no_opps = sgs[sgs.Team_x != sgs.Opponent_y]
sgs.drop(['Position_x', 'FPPG_x', 'Salary_x', 'Team_x', 'Opponent_x', 'Position_y', 'FPPG_y', 
         'Salary_y', 'Team_y', 'Opponent_y'], axis=1, inplace=True)

# %%
sgs.shape
# Out:
# (5700, 4)

# %% [markdown]
# ### SF's

# %%
sf.shape
# Out:
# (75, 6)

# %%
sfs = sf.assign(foo=1).merge(sf.assign(foo=1), on='foo').drop('foo', 1)
sfs = sfs[sfs.Nickname_x != sfs.Nickname_y]
sfs['ffpg'] = sfs.FPPG_x + sfs.FPPG_y
sfs['salary'] = sfs.Salary_x + sfs.Salary_y
sfs_no_opps = sfs[sfs.Team_x != sfs.Opponent_y]
sfs.drop(['Position_x', 'FPPG_x', 'Salary_x', 'Team_x', 'Opponent_x', 'Position_y', 'FPPG_y', 
         'Salary_y', 'Team_y', 'Opponent_y'], axis=1, inplace=True)

# %%
sfs.shape
# Out:
# (5550, 4)

# %% [markdown]
# ### PF's

# %%
pf.shape
# Out:
# (70, 6)

# %%
pfs = pf.assign(foo=1).merge(pf.assign(foo=1), on='foo').drop('foo', 1)
pfs = pfs[pfs.Nickname_x != pfs.Nickname_y]
pfs['ffpg'] = pfs.FPPG_x + pfs.FPPG_y
pfs['salary'] = pfs.Salary_x + pfs.Salary_y
pfs_no_opps = pfs[pfs.Team_x != pfs.Opponent_y]
pfs.drop(['Position_x', 'FPPG_x', 'Salary_x', 'Team_x', 'Opponent_x', 'Position_y', 'FPPG_y', 
         'Salary_y', 'Team_y', 'Opponent_y'], axis=1, inplace=True)

# %%
pfs.shape
# Out:
# (4830, 4)

# %%
# pfs = pfs[(pfs.Nickname_x != 'Anthony Davis') & (pfs.Nickname_y != 'Anthony Davis')]

# %% [markdown]
# ### Forwards

# %%
forwards = pfs.assign(foo=1).merge(sfs.assign(foo=1), on='foo').drop('foo', 1)
forwards['ffpg'] = forwards.ffpg_x + forwards.ffpg_y
forwards['salary'] = forwards.salary_x + forwards.salary_y
forwards.drop(['ffpg_x', 'salary_x', 'ffpg_y', 'salary_y'], axis=1, inplace=True)

# %%
forwards.head()
# Out:
#     Nickname_x_x       Nickname_y_x Nickname_x_y      Nickname_y_y  \
# 0  Julius Randle  LaMarcus Aldridge  Paul George      Kevin Durant
# 1  Julius Randle  LaMarcus Aldridge  Paul George     Kawhi Leonard
# 2  Julius Randle  LaMarcus Aldridge  Paul George  Danilo Gallinari
# 3  Julius Randle  LaMarcus Aldridge  Paul George        Joe Ingles
# 4  Julius Randle  LaMarcus Aldridge  Paul George  Bojan Bogdanovic
#
#          ffpg  salary
# 0  171.185982   37300
# 1  170.779360   36400
# 2  158.235104   35300
# 3  153.217157   34900
# 4  152.823923   34400

# %%
forwards.shape
# Out:
# (26806500, 6)

# %%
forwards = forwards.iloc[:500000, :]

# %% [markdown]
# ### Guards

# %%
guards = sgs.assign(foo=1).merge(pgs.assign(foo=1), on='foo').drop('foo', 1)
guards['ffpg'] = guards.ffpg_x + guards.ffpg_y
guards['salary'] = guards.salary_x + guards.salary_y
guards.drop(['ffpg_x', 'salary_x', 'ffpg_y', 'salary_y'], axis=1, inplace=True)

# %%
guards.columns = ['sg1', 'sg2', 'pg1', 'pg2', 'points', 'salary']
guards.shape
# Out:
# (18844200, 6)

# %%
guards = guards.iloc[:1000000,:]

# %%
guards = guards.sort_values(by='points', ascending=False)

# %%
gs = guards.iloc[::4, :]

# %%
guards.head()
# Out:
#                  sg1           sg2                pg1                pg2  \
# 3306    James Harden  Bradley Beal  Russell Westbrook      Stephen Curry
# 495900  Bradley Beal  James Harden  Russell Westbrook      Stephen Curry
# 3363    James Harden  Bradley Beal      Stephen Curry  Russell Westbrook
# 495957  Bradley Beal  James Harden      Stephen Curry  Russell Westbrook
# 3308    James Harden  Bradley Beal  Russell Westbrook       Kyrie Irving
#
#             points  salary
# 3306    200.930871   42300
# 495900  200.930871   42300
# 3363    200.930871   42300
# 495957  200.930871   42300
# 3308    200.795684   41900

# %%
gs.shape
# Out:
# (250000, 6)

# %%
# gs = gs[(gs.sg1 != 'Reggie Bullock') & (gs.sg2 != 'Reggie Bullock')]

# %% [markdown]
# ### Centers and Forwards

# %%
cfs = c.assign(foo=1).merge(forwards.assign(foo=1), on='foo').drop('foo', 1)
cfs['ffpg'] = cfs.FPPG + cfs.ffpg
cfs['salary'] = cfs.Salary + cfs.salary
cfs.drop(['Position', 'FPPG', 'Salary', 'Team', 'Opponent'], axis=1, inplace=True)

# %%
cfs.columns = ['c', 'pf1', 'pf2', 'sf1', 'sf2', 'points', 'salary']
cfs.shape
# Out:
# (21500000, 7)

# %%
cfs = cfs.sort_values(by=['points'], ascending=False)

# %%
cf = cfs.iloc[::4, :]

# %%
cf.head(2)
# Out:
#                          c                pf1                pf2  \
# 883024  Karl-Anthony Towns  LaMarcus Aldridge      Julius Randle
# 500148  Karl-Anthony Towns      Julius Randle  LaMarcus Aldridge
#
#                   sf1          sf2      points  salary
# 883024   Kevin Durant  Paul George  219.772826   48000
# 500148  Kawhi Leonard  Paul George  219.366203   47100

# %%
cf.shape
# Out:
# (5375000, 7)

# %% [markdown]
# ### Full Line

# %%
# cols = ['c', 'pf1', 'pf2', 'sf1', 'sf2', 'sg1', 'sg2', 'pg1', 'pg2', 'points', 'salary']
# df = pd.DataFrame(columns=cols)

# %%
# keep top 100, if < min of top 100, remove from gs
# take top 100 from line and concat
cols = ['c', 'pf1', 'pf2', 'sf1', 'sf2', 'sg1', 'sg2', 'pg1', 'pg2', 'points', 'salary']
df = pd.DataFrame(columns=cols)
t = time.time()
# gg = gs
for i in range(10000):
    gg = gs
    if df.shape[0] >= 100:
        df = df.sort_values(by=['points'], ascending=False)
        df = df.iloc[:100,:]
        gg =  gg[cf.iloc[i,5]+gg.points > df.points.min()]
       
    cap = gg[cf.iloc[i,6]+gg.salary<=60000]
    if cap.shape[0] > 0:
        cap = cap.sort_values(by=['points'], ascending=False)
        cap = cap.iloc[:100,:]
    else:
        continue
    r = cf.iloc[i,:].to_frame().transpose()
    row = pd.DataFrame(r).assign(foo=1).merge(cap.assign(foo=1), on='foo').drop('foo', 1)
    row['points'] = row.points_x + row.points_y
    row['salary'] = row.salary_x + row.salary_y
    row.drop(['points_x', 'points_y', 'salary_x', 'salary_y'], axis=1, inplace=True)
#     row = pd.concat([cf.iloc[i,:5], 
#            cap['sg1':'pg2'], 
#            pd.Series({'salary': cap.salary+cf.iloc[i,6]}),
#             pd.Series({'points': cap.points+cf.iloc[i,5]})])
    df = df.append(row, ignore_index=True)
    if i>0 and i%1000==0:
        print(i)
print('time:', time.time() - t)
df
# Out:
# time: 128.46276879310608
#                     c                pf1                pf2               sf1  \
# 0    Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 1          Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 2          Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 3          Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 4    Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 5    Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 6    Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 7    Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 8    Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 9    Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 10     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 11   Hassan Whiteside  LaMarcus Aldridge       John Collins   Nemanja Bjelica
# 12     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 13     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 14   Hassan Whiteside  LaMarcus Aldridge       John Collins   Nemanja Bjelica
# 15         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 16     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 17         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 18         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 19         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 20         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 21   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 22   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 23   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 24   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 25   Hassan Whiteside  LaMarcus Aldridge      Julius Randle   Nemanja Bjelica
# 26   Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 100        Marc Gasol  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 27   Hassan Whiteside      Julius Randle     Kenneth Faried      Kevin Durant
# 28   Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 29   Hassan Whiteside  LaMarcus Aldridge      Julius Randle   Nemanja Bjelica
# 30     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 31     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 32     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 101        Marc Gasol  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 33         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 34         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 35   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 36   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka  Danilo Gallinari
# 37   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 38   Hassan Whiteside      Julius Randle     Kenneth Faried      Kevin Durant
# 39   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 40   Hassan Whiteside      Julius Randle          PJ Tucker      Kevin Durant
# 41   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 42     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 43         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 44         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 45   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 46   Hassan Whiteside      Julius Randle    Markieff Morris     Kawhi Leonard
# 47         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 48   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 49     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 50   Hassan Whiteside      Julius Randle  LaMarcus Aldridge     Kawhi Leonard
# 51   Hassan Whiteside  LaMarcus Aldridge    Al-Farouq Aminu     Kawhi Leonard
# 52   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 53         Marc Gasol  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 54   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 55     DeAndre Jordan      Julius Randle     Kenneth Faried      Kevin Durant
# 56   Hassan Whiteside  LaMarcus Aldridge       John Collins   Justise Winslow
# 57         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 58       Nikola Jokic      Julius Randle        Serge Ibaka     Kawhi Leonard
# 59   Hassan Whiteside  LaMarcus Aldridge       Jerami Grant     Kawhi Leonard
# 60   Hassan Whiteside  LaMarcus Aldridge       Jayson Tatum   Justise Winslow
# 61     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 62   Hassan Whiteside  LaMarcus Aldridge       John Collins   Nemanja Bjelica
# 63         Marc Gasol  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 64   Hassan Whiteside      Julius Randle     Kenneth Faried      Kevin Durant
# 65         Marc Gasol  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 66   Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 67     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 68   Hassan Whiteside  LaMarcus Aldridge       John Collins   Nemanja Bjelica
# 69     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 70   Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 71     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 72     DeAndre Jordan      Julius Randle     Kenneth Faried      Kevin Durant
# 73     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 74         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 75         Marc Gasol  LaMarcus Aldridge      Julius Randle     Kawhi Leonard
# 76     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 77     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 78   Hassan Whiteside  LaMarcus Aldridge       John Collins   Nemanja Bjelica
# 79         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 80     DeAndre Jordan  LaMarcus Aldridge        Serge Ibaka     Kawhi Leonard
# 81   Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 82   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka  Danilo Gallinari
# 83   Hassan Whiteside      Julius Randle      James Johnson       Paul George
# 84   Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 85         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 86         Marc Gasol  LaMarcus Aldridge        Serge Ibaka      Kevin Durant
# 87   Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 88   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 89         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
# 90   Hassan Whiteside      Julius Randle          PJ Tucker      Kevin Durant
# 91   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 92   Hassan Whiteside      Julius Randle     Kenneth Faried     Kawhi Leonard
# 93   Hassan Whiteside  LaMarcus Aldridge        Serge Ibaka   Justise Winslow
# 94   Hassan Whiteside      Julius Randle        Serge Ibaka          Rudy Gay
# 95   Hassan Whiteside      Julius Randle    Markieff Morris     Kawhi Leonard
# 96     DeAndre Jordan      Julius Randle  LaMarcus Aldridge     Kawhi Leonard
# 97         Marc Gasol  LaMarcus Aldridge        Serge Ibaka       Paul George
#
#                  sf2            sg1                sg2                pg1  \
# 0        Paul George   Bradley Beal        Jeremy Lamb         Kyle Lowry
# 1    Justise Winslow   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 2    Harrison Barnes   Bradley Beal        Jeremy Lamb         Kyle Lowry
# 3    Justise Winslow   Bradley Beal    Dennis Schroder        Cory Joseph
# 4        Paul George   Bradley Beal       Monte Morris          Ish Smith
# 5        Paul George   Bradley Beal       Monte Morris         Jeremy Lin
# 6        Paul George   Bradley Beal       Monte Morris         Kyle Lowry
# 7        Paul George   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 8      Kawhi Leonard  DeMar DeRozan      Malik Beasley          Ish Smith
# 9        Paul George   Bradley Beal    Dennis Schroder        Cory Joseph
# 10       Paul George   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 11       Paul George   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 12       Paul George   Bradley Beal        Jeremy Lamb        Patty Mills
# 13       Paul George   Bradley Beal        Jeremy Lamb        Patty Mills
# 14       Paul George   Bradley Beal    Dennis Schroder        Cory Joseph
# 15   Harrison Barnes   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 16       Paul George   Bradley Beal    Dennis Schroder        Patty Mills
# 17   Justise Winslow   Bradley Beal  Bogdan Bogdanovic         Kyle Lowry
# 18   Harrison Barnes   Bradley Beal    Dennis Schroder        Cory Joseph
# 19   Justise Winslow   Bradley Beal        Jeremy Lamb         Kyle Lowry
# 20   Justise Winslow  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 21     Kawhi Leonard  DeMar DeRozan     Garrett Temple         Kyle Lowry
# 22     Kawhi Leonard  DeMar DeRozan      Malik Beasley         Kyle Lowry
# 23     Kawhi Leonard  DeMar DeRozan     Garrett Temple        Patty Mills
# 24       Paul George   Bradley Beal        Jeremy Lamb  De'Anthony Melton
# 25     Kawhi Leonard   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 26       Paul George   Bradley Beal      Malik Beasley         Kyle Lowry
# 100         Rudy Gay   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 27     Kawhi Leonard  DeMar DeRozan    Dennis Schroder         Kyle Lowry
# 28       Paul George  DeMar DeRozan        Danny Green         Kyle Lowry
# 29     Kawhi Leonard   Bradley Beal    Dennis Schroder        Cory Joseph
# 30       Paul George   Bradley Beal        Jeremy Lamb        Tony Parker
# 31      Kevin Durant  DeMar DeRozan     Garrett Temple         Kyle Lowry
# 32       Paul George   Bradley Beal    Dennis Schroder        Tony Parker
# 101         Rudy Gay   Bradley Beal    Dennis Schroder        Cory Joseph
# 33   Justise Winslow   Bradley Beal  Bogdan Bogdanovic        Tony Parker
# 34   Justise Winslow   Bradley Beal    Dennis Schroder        Tony Parker
# 35     Kawhi Leonard  DeMar DeRozan         Alec Burks         Kyle Lowry
# 36     Kawhi Leonard   Bradley Beal    Dennis Schroder        Tony Parker
# 37     Kawhi Leonard  DeMar DeRozan      Austin Rivers          Ish Smith
# 38     Kawhi Leonard   Bradley Beal       Monte Morris        Cory Joseph
# 39     Kawhi Leonard  DeMar DeRozan      Austin Rivers         Kyle Lowry
# 40     Kawhi Leonard  DeMar DeRozan    Dennis Schroder         Kyle Lowry
# 41     Kawhi Leonard  DeMar DeRozan    Rodney McGruder          Ish Smith
# 42      Kevin Durant  DeMar DeRozan     Garrett Temple        Patty Mills
# 43   Harrison Barnes   Bradley Beal        Jeremy Lamb  De'Anthony Melton
# 44   Justise Winslow   Bradley Beal    Dennis Schroder         Kyle Lowry
# 45       Paul George   Bradley Beal  Bogdan Bogdanovic         Kyle Lowry
# 46      Kevin Durant   Bradley Beal    Dennis Schroder        Tony Parker
# 47   Justise Winslow   Bradley Beal        Eric Gordon         Kyle Lowry
# 48       Paul George   Bradley Beal        Jeremy Lamb         Kyle Lowry
# 49       Paul George   Bradley Beal  Bogdan Bogdanovic         Jeremy Lin
# 50     Nicolas Batum  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 51       Paul George  DeMar DeRozan         Alec Burks        Cory Joseph
# 52     Kawhi Leonard  DeMar DeRozan      Malik Beasley       Shelvin Mack
# 53     Kawhi Leonard   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 54       Paul George  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 55     Kawhi Leonard  DeMar DeRozan    Dennis Schroder         Kyle Lowry
# 56     Kawhi Leonard  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 57   Justise Winslow  DeMar DeRozan        Danny Green     Reggie Jackson
# 58   Nemanja Bjelica  DeMar DeRozan    Dennis Schroder         Kyle Lowry
# 59      Kevin Durant  DeMar DeRozan         Alec Burks        Cory Joseph
# 60       Paul George  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 61       Paul George   Bradley Beal  Bogdan Bogdanovic          Ish Smith
# 62       Paul George   Bradley Beal  Bogdan Bogdanovic         Kyle Lowry
# 63     Kawhi Leonard   Bradley Beal        Jeremy Lamb        Patty Mills
# 64     Kawhi Leonard   Bradley Beal     Justin Holiday          Ish Smith
# 65     Kawhi Leonard   Bradley Beal        Jeremy Lamb        Patty Mills
# 66       Paul George  DeMar DeRozan     Justin Holiday          Ish Smith
# 67       Paul George   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 68       Paul George   Bradley Beal        Jeremy Lamb         Kyle Lowry
# 69      Kevin Durant  DeMar DeRozan         Alec Burks         Kyle Lowry
# 70       Paul George   Bradley Beal     Garrett Temple        Cory Joseph
# 71      Kevin Durant  DeMar DeRozan      Austin Rivers          Ish Smith
# 72     Kawhi Leonard   Bradley Beal       Monte Morris        Cory Joseph
# 73       Paul George  DeMar DeRozan        Jeremy Lamb        Cory Joseph
# 74   Justise Winslow  DeMar DeRozan       Monte Morris     Reggie Jackson
# 75     Nicolas Batum  DeMar DeRozan        Jeremy Lamb          Ish Smith
# 76      Kevin Durant  DeMar DeRozan      Austin Rivers         Kyle Lowry
# 77       Paul George  DeMar DeRozan        Jeremy Lamb        Cory Joseph
# 78       Paul George  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 79   Justise Winslow  DeMar DeRozan        Jeremy Lamb          Ish Smith
# 80      Kevin Durant  DeMar DeRozan    Rodney McGruder          Ish Smith
# 81       Paul George   Bradley Beal         Alec Burks         Kyle Lowry
# 82     Kawhi Leonard  DeMar DeRozan        Jeremy Lamb          Ish Smith
# 83     Kawhi Leonard  DeMar DeRozan    Dennis Schroder         Kyle Lowry
# 84       Paul George   Bradley Beal        Jeremy Lamb         Jeremy Lin
# 85   Harrison Barnes   Bradley Beal  Bogdan Bogdanovic         Kyle Lowry
# 86     Kawhi Leonard   Bradley Beal    Dennis Schroder        Patty Mills
# 87       Paul George   Bradley Beal         Alec Burks         Jeremy Lin
# 88       Paul George  DeMar DeRozan     Justin Holiday         Kyle Lowry
# 89   Harrison Barnes   Bradley Beal        Jeremy Lamb         Kyle Lowry
# 90     Kawhi Leonard   Bradley Beal     Justin Holiday          Ish Smith
# 91       Paul George  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 92       Paul George   Bradley Beal        Jeremy Lamb     Reggie Jackson
# 93       Paul George   Bradley Beal      Evan Fournier         Kyle Lowry
# 94       Paul George  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 95      Kevin Durant  DeMar DeRozan        Jeremy Lamb          Ish Smith
# 96     Nicolas Batum  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
# 97   Harrison Barnes  DeMar DeRozan        Jeremy Lamb         Kyle Lowry
#
#                    pg2   points salary
# 0          Cory Joseph  306.649  59900
# 1           Kyle Lowry  306.289  60000
# 2          Cory Joseph  306.068  59900
# 3           Kyle Lowry  306.052  60000
# 4           Kyle Lowry  305.431  60000
# 5           Kyle Lowry  305.404  60000
# 6          Patty Mills  305.242  60000
# 7           Kyle Lowry  305.094  59500
# 8           Kyle Lowry  305.049  60000
# 9           Kyle Lowry  304.857  59500
# 10           Ish Smith  304.809  60000
# 11          Kyle Lowry  304.776  59900
# 12           Ish Smith  304.648  60000
# 13          Jeremy Lin  304.621  60000
# 14          Kyle Lowry  304.539  59900
# 15          Kyle Lowry  304.513  59500
# 16         Cory Joseph  304.384  60000
# 17         Patty Mills   304.36  60000
# 18          Kyle Lowry  304.276  59500
# 19        Shelvin Mack   304.27  60000
# 20         Cory Joseph   304.17  59800
# 21           Ish Smith  304.026  59900
# 22         Tony Parker  303.876  60000
# 23          Kyle Lowry  303.838  59900
# 24          Kyle Lowry  303.774  59800
# 25          Kyle Lowry  303.744  59800
# 26         Cory Joseph  303.728  59900
# 100         Kyle Lowry  303.631  59900
# 27          Jeremy Lin  303.581  59700
# 28         Cory Joseph  303.546  59900
# 29          Kyle Lowry  303.507  59800
# 30         Patty Mills  303.475  60000
# 31           Ish Smith  303.403  60000
# 32         Cory Joseph  303.399  60000
# 101         Kyle Lowry  303.393  59900
# 33          Kyle Lowry  303.376  60000
# 34          Kyle Lowry   303.35  59600
# 35        Shelvin Mack  303.349  59800
# 36          Kyle Lowry  303.323  59900
# 37          Kyle Lowry  303.322  59900
# 38          Kyle Lowry  303.317  59900
# 39          Jeremy Lin  303.295  59900
# 40          Jeremy Lin  303.268  59900
# 41          Kyle Lowry  303.248  59800
# 42          Kyle Lowry  303.215  60000
# 43          Kyle Lowry  303.193  59800
# 44   De'Anthony Melton  303.177  59900
# 45         Patty Mills  303.166  59500
# 46          Kyle Lowry  303.108  59900
# 47         Cory Joseph  303.094  60000
# 48        Shelvin Mack  303.075  59500
# 49           Ish Smith  303.043  60000
# 50         Cory Joseph  303.019  59900
# 51          Kyle Lowry  303.008  60000
# 52          Kyle Lowry  303.004  60000
# 53           Ish Smith  302.986  59900
# 54         Cory Joseph  302.975  59300
# 55          Jeremy Lin  302.958  59800
# 56         Cory Joseph  302.955  59900
# 57          Kyle Lowry  302.947  60000
# 58          Jeremy Lin  302.924  60000
# 59          Kyle Lowry  302.905  59900
# 60         Cory Joseph  302.887  60000
# 61         Patty Mills  302.881  60000
# 62         Patty Mills  302.848  59900
# 63           Ish Smith  302.824  59900
# 64          Kyle Lowry  302.798  59800
# 65          Jeremy Lin  302.797  59900
# 66          Kyle Lowry  302.766  59700
# 67        Shelvin Mack  302.764  60000
# 68        Shelvin Mack  302.757  59900
# 69        Shelvin Mack  302.726  59900
# 70          Kyle Lowry  302.705  59800
# 71          Kyle Lowry  302.699  60000
# 72          Kyle Lowry  302.694  60000
# 73           Ish Smith   302.69  59800
# 74          Kyle Lowry  302.687  59900
# 75          Kyle Lowry  302.685  60000
# 76          Jeremy Lin  302.672  60000
# 77          Jeremy Lin  302.664  59800
# 78         Cory Joseph  302.657  59700
# 79          Kyle Lowry  302.642  59400
# 80          Kyle Lowry  302.625  59900
# 81          Trey Burke  302.619  60000
# 82          Kyle Lowry  302.614  59700
# 83          Jeremy Lin   302.61  60000
# 84      Reggie Jackson  302.598  60000
# 85         Patty Mills  302.585  59500
# 86         Cory Joseph   302.56  59900
# 87          Kyle Lowry  302.519  59300
# 88      Reggie Jackson  302.501  59700
# 89        Shelvin Mack  302.494  59500
# 90          Kyle Lowry  302.484  60000
# 91         Bryn Forbes  302.479  59600
# 92         Patty Mills  302.436  60000
# 93           Ish Smith  302.423  59900
# 94         Cory Joseph  302.422  59900
# 95          Kyle Lowry  302.399  59700
# 96         Cory Joseph  302.395  60000
# 97         Cory Joseph  302.394  59300

# %%
# set(gs.iloc[1, 0:4].values.tolist()) == set(gs.iloc[2,0:4].values.tolist())

# dups = []
# for i in range(gs.shape[0]-1):
#     check = set(gs.iloc[i, 0:4].values.tolist()) == set(gs.iloc[i+1,0:4].values.tolist())
#     dups.append(check)
# dups = dups + [False]

# %%
# try guards vs cfs instead
